# %% [markdown]
# ## Codigo para analizar instancias pequeñas

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import scipy as sp
import pandas as pd
import random

# %%
def read_out(lineas):
    matrix = []
    experiment = []

    caract_matrix = []
    caract = []

    flag = True
    for linea in lineas:
        if flag:
            caract.append(linea)
            flag = False
            continue
        try:
            experiment.append(int(linea));
        except:
            if "BEST" in linea or "Time:" in linea:
                caract.append(linea)
                continue
            caract_matrix.append(caract)
            matrix.append(experiment)
            experiment = []
            caract = []
            caract.append(linea)
    return caract_matrix, matrix

# %%
with open("./OutputPPP/out_Ian07.txt", "r") as fp:
    lineas = fp.read().split("\n")
    
caract_matrix, matrix = read_out(lineas)

for i in range(len(caract_matrix)):
    print(str(i) + ":" + str(caract_matrix[i]))
# Out:
# 0:['cant_hosts=1;max_resets=100;CAPA penalty=1;DIFF penalty=1;ONCE penalty=1', 'BEST SOL EVAL: 240', 'Time: 1.000000 sec']
# 1:['cant_hosts=1;max_resets=100;CAPA penalty=1;DIFF penalty=1;ONCE penalty=5', 'BEST SOL EVAL: 960', 'Time: 0.00000 sec']
# 2:['cant_hosts=1;max_resets=100;CAPA penalty=1;DIFF penalty=5;ONCE penalty=1', 'BEST SOL EVAL: 400', 'Time: 1.00000 sec']
# 3:['cant_hosts=1;max_resets=100;CAPA penalty=5;DIFF penalty=1;ONCE penalty=1', 'BEST SOL EVAL: 320', 'Time: 0.00000 sec']
# 4:['cant_hosts=1;max_resets=1000;CAPA penalty=1;DIFF penalty=1;ONCE penalty=1', 'BEST SOL EVAL: 240', 'Time: 5.00000 sec']
# 5:['cant_hosts=1;max_resets=1000;CAPA penalty=1;DIFF penalty=1;ONCE penalty=5', 'BEST SOL EVAL: 960', 'Time: 6.00000 sec']
# 6:['cant_hosts=1;max_resets=1000;CAPA penalty=1;DIFF penalty=5;ONCE penalty=1', 'BEST SOL EVAL: 400', 'Time: 5.00000 sec']
# 7:['cant_hosts=1;max_resets=1000;CAPA penalty=5;DIFF penalty=1;ONCE penalty=1', 'BEST SOL EVAL: 320', 'Time: 5.00000 sec']
# 8:['cant_hosts=2;max_resets=100;CAPA penalty=1;DIFF penalty=1;ONCE penalty=1', 'BEST SOL EVAL: 76', 'Time: 3.00000 sec']
# 9:['cant_hosts=2;max_resets=100;CAPA penalty=1;DIFF penalty=1;ONCE penalty=5', 'BEST SOL EVAL: 252', 'Time: 2.00000 sec']
# 10:['cant_hosts=2;max_resets=100;CAPA penalty=1;DIFF penalty=5;ONCE penalty=1', 'BEST SOL EVAL: 184', 'Time: 3.00000 sec']
# 11:['cant_hosts=2;max_resets=100;CAPA penalty=5;DIFF penalty=1;ONCE penalty=1', 'BEST SOL EVAL: 98', 'Time: 1.00000 sec']
# 12:['cant_hosts=2;max_resets=1000;CAPA penalty=1;DIFF penalty=1;ONCE penalty=1', 'BEST SOL EVAL: 76', 'Time: 18.00000 sec']
# 13:['cant_hosts=2;max_resets=1000;CAPA penalty=1;DIFF penalty=1;ONCE penalty=5', 'BEST SOL EVAL: 252', 'Time: 19.00000 sec']
# 14:['cant_hosts=2;max_resets=1000;CAPA penalty=1;DIFF penalty=5;ONCE penalty=1', 'BEST SOL EVAL: 184', 'Time: 25.00000 sec']
# 15:['cant_hosts=2;max_resets=1000;CAPA penalty=5;DIFF penalty=1;ONCE penalty=1', 'BEST SOL EVAL: 96', 'Time: 17.00000 sec']
# 16:['cant_hosts=3;max_resets=100;CAPA penalty=1;DIFF penalty=1;ONCE penalty=1', 'BEST SOL EVAL: 26', 'Time: 4.00000 sec']
# 17:['cant_hosts=3;max_resets=100;CAPA penalty=1;DIFF penalty=1;ONCE penalty=5', 'BEST SOL EVAL: 53', 'Time: 5.00000 sec']
# 18:['cant_hosts=3;max_resets=100;CAPA penalty=1;DIFF penalty=5;ONCE penalty=1', 'BEST SOL EVAL: 88', 'Time: 6.00000 sec']
# 19:['cant_hosts=3;max_resets=100;CAPA penalty=5;DIFF penalty=1;ONCE penalty=1', 'BEST SOL EVAL: 24', 'Time: 4.00000 sec']
# 20:['cant_hosts=3;max_resets=1000;CAPA penalty=1;DIFF penalty=1;ONCE penalty=1', 'BEST SOL EVAL: 23', 'Time: 38.00000 sec']
# 21:['cant_hosts=3;max_resets=1000;CAPA penalty=1;DIFF penalty=1;ONCE penalty=5', 'BEST SOL EVAL: 52', 'Time: 36.00000 sec']
# 22:['cant_hosts=3;max_resets=1000;CAPA penalty=1;DIFF penalty=5;ONCE penalty=1', 'BEST SOL EVAL: 87', 'Time: 49.00000 sec']
# 23:['cant_hosts=3;max_resets=1000;CAPA penalty=5;DIFF penalty=1;ONCE penalty=1', 'BEST SOL EVAL: 23', 'Time: 37.00000 sec']
# 24:['cant_hosts=4;max_resets=100;CAPA penalty=1;DIFF penalty=1;ONCE penalty=1', 'BEST SOL EVAL: 12', 'Time: 3.00000 sec']
# 25:['cant_hosts=4;max_resets=100;CAPA penalty=1;DIFF penalty=1;ONCE penalty=5', 'BEST SOL EVAL: 12', 'Time: 2.00000 sec']
# 26:['cant_hosts=4;max_resets=100;CAPA penalty=1;DIFF penalty=5;ONCE penalty=1', 'BEST SOL EVAL: 37', 'Time: 6.00000 sec']
# 27:['cant_hosts=4;max_resets=100;CAPA penalty=5;DIFF penalty=1;ONCE penalty=1', 'BEST SOL EVAL: 8', 'Time: 3.00000 sec']
# 28:['cant_hosts=4;max_resets=1000;CAPA penalty=1;DIFF penalty=1;ONCE penalty=1', 'BEST SOL EVAL: 7', 'Time: 32.00000 sec']
# 29:['cant_hosts=4;max_resets=1000;CAPA penalty=1;DIFF penalty=1;ONCE penalty=5', 'BEST SOL EVAL: 11', 'Time: 31.00000 sec']
# 30:['cant_hosts=4;max_resets=1000;CAPA penalty=1;DIFF penalty=5;ONCE penalty=1', 'BEST SOL EVAL: 35', 'Time: 52.00000 sec']
# 31:['cant_hosts=4;max_resets=1000;CAPA penalty=5;DIFF penalty=1;ONCE penalty=1', 'BEST SOL EVAL: 10', 'Time: 25.00000 sec']
# 32:['cant_hosts=5;max_resets=100;CAPA penalty=1;DIFF penalty=1;ONCE penalty=1', 'BEST SOL EVAL: 5', 'Time: 2.00000 sec']
# 33:['cant_hosts=5;max_resets=100;CAPA penalty=1;DIFF penalty=1;ONCE penalty=5', 'BEST SOL EVAL: 7', 'Time: 2.00000 sec']
# 34:['cant_hosts=5;max_resets=100;CAPA penalty=1;DIFF penalty=5;ONCE penalty=1', 'BEST SOL EVAL: 4', 'Time: 4.00000 sec']
# 35:['cant_hosts=5;max_resets=100;CAPA penalty=5;DIFF penalty=1;ONCE penalty=1', 'BEST SOL EVAL: 3', 'Time: 2.00000 sec']
# 36:['cant_hosts=5;max_resets=1000;CAPA penalty=1;DIFF penalty=1;ONCE penalty=1', 'BEST SOL EVAL: 3', 'Time: 24.00000 sec']
# 37:['cant_hosts=5;max_resets=1000;CAPA penalty=1;DIFF penalty=1;ONCE penalty=5', 'BEST SOL EVAL: 3', 'Time: 22.00000 sec']
# 38:['cant_hosts=5;max_resets=1000;CAPA penalty=1;DIFF penalty=5;ONCE penalty=1', 'BEST SOL EVAL: 4', 'Time: 37.00000 sec']
# 39:['cant_hosts=5;max_resets=1000;CAPA penalty=5;DIFF penalty=1;ONCE penalty=1', 'BEST SOL EVAL: 3', 'Time: 23.00000 sec']
# 40:['cant_hosts=6;max_resets=100;CAPA penalty=1;DIFF penalty=1;ONCE penalty=1', 'BEST SOL EVAL: 1', 'Time: 1.00000 sec']
# 41:['cant_hosts=6;max_resets=100;CAPA penalty=1;DIFF penalty=1;ONCE penalty=5', 'BEST SOL EVAL: 1', 'Time: 1.00000 sec']
# 42:['cant_hosts=6;max_resets=100;CAPA penalty=1;DIFF penalty=5;ONCE penalty=1', 'BEST SOL EVAL: 1', 'Time: 2.00000 sec']
# 43:['cant_hosts=6;max_resets=100;CAPA penalty=5;DIFF penalty=1;ONCE penalty=1', 'BEST SOL EVAL: 1', 'Time: 2.00000 sec']
# 44:['cant_hosts=6;max_resets=1000;CAPA penalty=1;DIFF penalty=1;ONCE penalty=1', 'BEST SOL EVAL: 0', 'Time: 14.00000 sec']
# 45:['cant_hosts=6;max_resets=1000;CAPA penalty=1;DIFF penalty=1;ONCE penalty=5', 'BEST SOL EVAL: 0', 'Time: 16.00000 sec']
# 46:['cant_hosts=6;max_resets=1000;CAPA penalty=1;DIFF penalty=5;ONCE penalty=1', 'BEST SOL EVAL: 0', 'Time: 22.00000 sec']
# 47:['cant_hosts=6;max_resets=1000;CAPA penalty=5;DIFF penalty=1;ONCE penalty=1', 'BEST SOL EVAL: 0', 'Time: 15.00000 sec']
# 48:['cant_hosts=7;max_resets=100;CAPA penalty=1;DIFF penalty=1;ONCE penalty=1', 'BEST SOL EVAL: 0', 'Time: 0.00000 sec']
# 49:['cant_hosts=7;max_resets=100;CAPA penalty=1;DIFF penalty=1;ONCE penalty=5', 'BEST SOL EVAL: 1', 'Time: 1.00000 sec']
# 50:['cant_hosts=7;max_resets=100;CAPA penalty=1;DIFF penalty=5;ONCE penalty=1', 'BEST SOL EVAL: 0', 'Time: 1.00000 sec']
# 51:['cant_hosts=7;max_resets=100;CAPA penalty=5;DIFF penalty=1;ONCE penalty=1', 'BEST SOL EVAL: 1', 'Time: 1.00000 sec']
# 52:['cant_hosts=7;max_resets=1000;CAPA penalty=1;DIFF penalty=1;ONCE penalty=1', 'BEST SOL EVAL: 0', 'Time: 6.00000 sec']
# 53:['cant_hosts=7;max_resets=1000;CAPA penalty=1;DIFF penalty=1;ONCE penalty=5', 'BEST SOL EVAL: 0', 'Time: 8.00000 sec']
# 54:['cant_hosts=7;max_resets=1000;CAPA penalty=1;DIFF penalty=5;ONCE penalty=1', 'BEST SOL EVAL: 0', 'Time: 10.00000 sec']
# 55:['cant_hosts=7;max_resets=1000;CAPA penalty=5;DIFF penalty=1;ONCE penalty=1', 'BEST SOL EVAL: 0', 'Time: 6.00000 sec']
# 56:['cant_hosts=8;max_resets=100;CAPA penalty=1;DIFF penalty=1;ONCE penalty=1', 'BEST SOL EVAL: 0', 'Time: 0.00000 sec']
# 57:['cant_hosts=8;max_resets=100;CAPA penalty=1;DIFF penalty=1;ONCE penalty=5', 'BEST SOL EVAL: 0', 'Time: 0.00000 sec']
# 58:['cant_hosts=8;max_resets=100;CAPA penalty=1;DIFF penalty=5;ONCE penalty=1', 'BEST SOL EVAL: 0', 'Time: 0.00000 sec']
# 59:['cant_hosts=8;max_resets=100;CAPA penalty=5;DIFF penalty=1;ONCE penalty=1', 'BEST SOL EVAL: 0', 'Time: 1.00000 sec']
# 60:['cant_hosts=8;max_resets=1000;CAPA penalty=1;DIFF penalty=1;ONCE penalty=1', 'BEST SOL EVAL: 0', 'Time: 2.00000 sec']
# 61:['cant_hosts=8;max_resets=1000;CAPA penalty=1;DIFF penalty=1;ONCE penalty=5', 'BEST SOL EVAL: 0', 'Time: 3.00000 sec']
# 62:['cant_hosts=8;max_resets=1000;CAPA penalty=1;DIFF penalty=5;ONCE penalty=1', 'BEST SOL EVAL: 0', 'Time: 3.00000 sec']
# 63:['cant_hosts=8;max_resets=1000;CAPA penalty=5;DIFF penalty=1;ONCE penalty=1', 'BEST SOL EVAL: 0', 'Time: 3.00000 sec']
# 64:['cant_hosts=9;max_resets=100;CAPA penalty=1;DIFF penalty=1;ONCE penalty=1', 'BEST SOL EVAL: 0', 'Time: 0.00000 sec']
# 65:['cant_hosts=9;max_resets=100;CAPA penalty=1;DIFF penalty=1;ONCE penalty=5', 'BEST SOL EVAL: 0', 'Time: 0.00000 sec']
# 66:['cant_hosts=9;max_resets=100;CAPA penalty=1;DIFF penalty=5;ONCE penalty=1', 'BEST SOL EVAL: 0', 'Time: 0.00000 sec']
# 67:['cant_hosts=9;max_resets=100;CAPA penalty=5;DIFF penalty=1;ONCE penalty=1', 'BEST SOL EVAL: 0', 'Time: 0.00000 sec']
# 68:['cant_hosts=9;max_resets=1000;CAPA penalty=1;DIFF penalty=1;ONCE penalty=1', 'BEST SOL EVAL: 0', 'Time: 0.00000 sec']
# 69:['cant_hosts=9;max_resets=1000;CAPA penalty=1;DIFF penalty=1;ONCE penalty=5', 'BEST SOL EVAL: 0', 'Time: 2.00000 sec']
# 70:['cant_hosts=9;max_resets=1000;CAPA penalty=1;DIFF penalty=5;ONCE penalty=1', 'BEST SOL EVAL: 0', 'Time: 1.00000 sec']
# 71:['cant_hosts=9;max_resets=1000;CAPA penalty=5;DIFF penalty=1;ONCE penalty=1', 'BEST SOL EVAL: 0', 'Time: 1.00000 sec']
# 72:['cant_hosts=10;max_resets=100;CAPA penalty=1;DIFF penalty=1;ONCE penalty=1', 'BEST SOL EVAL: 0', 'Time: 0.00000 sec']
# 73:['cant_hosts=10;max_resets=100;CAPA penalty=1;DIFF penalty=1;ONCE penalty=5', 'BEST SOL EVAL: 0', 'Time: 0.00000 sec']
# 74:['cant_hosts=10;max_resets=100;CAPA penalty=1;DIFF penalty=5;ONCE penalty=1', 'BEST SOL EVAL: 0', 'Time: 0.00000 sec']
# 75:['cant_hosts=10;max_resets=100;CAPA penalty=5;DIFF penalty=1;ONCE penalty=1', 'BEST SOL EVAL: 0', 'Time: 0.00000 sec']
# 76:['cant_hosts=10;max_resets=1000;CAPA penalty=1;DIFF penalty=1;ONCE penalty=1', 'BEST SOL EVAL: 0', 'Time: 0.00000 sec']
# 77:['cant_hosts=10;max_resets=1000;CAPA penalty=1;DIFF penalty=1;ONCE penalty=5', 'BEST SOL EVAL: 0', 'Time: 0.00000 sec']
# 78:['cant_hosts=10;max_resets=1000;CAPA penalty=1;DIFF penalty=5;ONCE penalty=1', 'BEST SOL EVAL: 0', 'Time: 0.00000 sec']
# 79:['cant_hosts=10;max_resets=1000;CAPA penalty=5;DIFF penalty=1;ONCE penalty=1', 'BEST SOL EVAL: 0', 'Time: 1.00000 sec']

# %%
def resets_quality(matrix):
    best_resets = []
    aux_bests = []
    for arr in matrix:
        aux_bests = []
        for i in range(len(arr)-1):
            if(arr[i] < arr[i+1]):
                aux_bests.append(arr[i])
            #print(arr[i])
        aux_bests.append(arr[-1])
        best_resets.append(aux_bests)
    return best_resets

# %%
h1r100 = resets_quality(matrix[0:4])
plt.figure(figsize = (12,6))
plt.boxplot(h1r100)
plt.title("Ian10 ; Cant_Hosts = 1 ; Resets = 100")
plt.xlabel("Multiplicador de Penalizaciones")
plt.ylabel("Costo por penalizaciones")
plt.xticks([1, 2, 3, 4], ['CP=1 DP=1 OP=1', 'CP=1 DP=1 OP=5', 'CP=1 DP=5 OP=1', 'CP=5 DP=1 OP=1'], rotation = 30)
plt.show()

# %%
h1r1000 = resets_quality(matrix[4:8])
plt.figure(figsize = (12,6))
plt.boxplot(h1r1000)
plt.title("Ian10 ; Cant_Hosts = 1 ; Resets = 1000")
plt.xlabel("Multiplicador de Penalizaciones")
plt.ylabel("Costo por penalizaciones")
plt.xticks([1, 2, 3, 4], ['CP=1 DP=1 OP=1', 'CP=1 DP=1 OP=5', 'CP=1 DP=5 OP=1', 'CP=5 DP=1 OP=1'], rotation = 30)
plt.show()

# %%
plt.figure(figsize = (12,6))
plt.plot(matrix[4])
plt.title("Ian10 ; Cant_Hosts = 1 ; Resets = 1000")
plt.xlabel("Iteración")
plt.ylabel("Valor de la fx de evaluación (Calidad de la solución)")
#plt.xticks([1, 2, 3, 4], ['CP=1 DP=1 OP=1', 'CP=1 DP=1 OP=5', 'CP=1 DP=5 OP=1', 'CP=5 DP=1 OP=1'], rotation = 30)
plt.show()

# %%
h4r100 = resets_quality(matrix[24:28])
plt.figure(figsize = (12,6))
plt.boxplot(h4r100)
plt.title("Ian10 ; Cant_Hosts = 4 ; Resets = 100")
plt.xlabel("Multiplicador de Penalizaciones")
plt.ylabel("Costo por penalizaciones")
plt.xticks([1, 2, 3, 4], ['CP=1 DP=1 OP=1', 'CP=1 DP=1 OP=5', 'CP=1 DP=5 OP=1', 'CP=5 DP=1 OP=1'], rotation = 30)
plt.show()

# %%
h4r1000 = resets_quality(matrix[28:32])
plt.figure(figsize = (12,6))
plt.boxplot(h4r1000)
plt.title("Ian10 ; Cant_Hosts = 4 ; Resets = 1000")
plt.xlabel("Multiplicador de Penalizaciones")
plt.ylabel("Costo por penalizaciones")
plt.xticks([1, 2, 3, 4], ['CP=1 DP=1 OP=1', 'CP=1 DP=1 OP=5', 'CP=1 DP=5 OP=1', 'CP=5 DP=1 OP=1'], rotation = 30)
plt.show()

# %%
h6r100 = resets_quality(matrix[40:44])
plt.figure(figsize = (12,6))
plt.boxplot(h6r100)
plt.title("Ian10 ; Cant_Hosts = 6 ; Resets = 100")
plt.xlabel("Multiplicador de Penalizaciones")
plt.ylabel("Costo por penalizaciones")
plt.xticks([1, 2, 3, 4], ['CP=1 DP=1 OP=1', 'CP=1 DP=1 OP=5', 'CP=1 DP=5 OP=1', 'CP=5 DP=1 OP=1'], rotation = 30)
plt.show()

# %%
h6r1000 = resets_quality(matrix[44:48])
plt.figure(figsize = (12,6))
plt.boxplot(h6r1000)
plt.title("Ian10 ; Cant_Hosts = 6 ; Resets = 1000")
plt.xlabel("Multiplicador de Penalizaciones")
plt.ylabel("Costo por penalizaciones")
plt.xticks([1, 2, 3, 4], ['CP=1 DP=1 OP=1', 'CP=1 DP=1 OP=5', 'CP=1 DP=5 OP=1', 'CP=5 DP=1 OP=1'], rotation = 30)
plt.show()

# %%
h8r100 = resets_quality(matrix[56:60])
plt.figure(figsize = (12,6))
plt.boxplot(h8r100)
plt.title("Ian10 ; Cant_Hosts = 8 ; Resets = 100")
plt.xlabel("Multiplicador de Penalizaciones")
plt.ylabel("Costo por penalizaciones")
plt.xticks([1, 2, 3, 4], ['CP=1 DP=1 OP=1', 'CP=1 DP=1 OP=5', 'CP=1 DP=5 OP=1', 'CP=5 DP=1 OP=1'], rotation = 30)
plt.show()

# %%
h8r1000 = resets_quality(matrix[60:64])
plt.figure(figsize = (12,6))
plt.boxplot(h8r1000)
plt.title("Ian10 ; Cant_Hosts = 8 ; Resets = 1000")
plt.xlabel("Multiplicador de Penalizaciones")
plt.ylabel("Costo por penalizaciones")
plt.xticks([1, 2, 3, 4], ['CP=1 DP=1 OP=1', 'CP=1 DP=1 OP=5', 'CP=1 DP=5 OP=1', 'CP=5 DP=1 OP=1'], rotation = 30)
plt.show()

# %%
plt.figure(figsize = (12,6))
plt.plot(matrix[62][:100])
plt.title("Ian10 ; Cant_Hosts = 8 ; Resets = 1000 ; CP = 1 ; DP= 5 ; OP = 1")
plt.xlabel("Iteración")
plt.ylabel("Valor de la fx de evaluación (Calidad de la solución)")
#plt.xticks([1, 2, 3, 4], ['CP=1 DP=1 OP=1', 'CP=1 DP=1 OP=5', 'CP=1 DP=5 OP=1', 'CP=5 DP=1 OP=1'], rotation = 30)
plt.show()

# %% [markdown]
# ## Codigo para analizar configuraciones de PPP de 42 yates y 13 hosts

# %%
configs = ["config1","config2","config3","config4","config5","config6"]
outs = []
all_outs = []
for conf in configs:
    with open("./BigOutputPPP/"+conf+".txt") as fp:
        lineas = fp.read().split("\n")
    caract_matrix, matrix = read_out(lineas)
    print(caract_matrix)
    all_outs.append(matrix[0])
    outs.append(resets_quality(matrix)[0])
# Out:
# [['cant_hosts=13;max_resets=10;CAPA penalty=1;DIFF penalty=1;ONCE penalty=1', 'BEST SOL EVAL: 192', 'Time: 2440.000000 sec']]
# [['cant_hosts=13;max_resets=10;CAPA penalty=1;DIFF penalty=1;ONCE penalty=1', 'BEST SOL EVAL: 187', 'Time: 2758.000000 sec']]
# [['cant_hosts=13;max_resets=10;CAPA penalty=1;DIFF penalty=1;ONCE penalty=1', 'BEST SOL EVAL: 194', 'Time: 2312.000000 sec']]
# [['cant_hosts=13;max_resets=10;CAPA penalty=1;DIFF penalty=1;ONCE penalty=1', 'BEST SOL EVAL: 201', 'Time: 2164.000000 sec']]
# [['cant_hosts=13;max_resets=10;CAPA penalty=1;DIFF penalty=1;ONCE penalty=1', 'BEST SOL EVAL: 205', 'Time: 2189.000000 sec']]
# [['cant_hosts=13;max_resets=10;CAPA penalty=1;DIFF penalty=1;ONCE penalty=1', 'BEST SOL EVAL: 211', 'Time: 2104.000000 sec']]

# %%
best_outputs = resets_quality(outs)
plt.figure(figsize = (12,6))
plt.boxplot(best_outputs)
plt.title(caract_matrix[0][0])
plt.xlabel("Multiplicador de Penalizaciones")
plt.ylabel("Configuraciones")
plt.xticks([1, 2, 3, 4, 5, 6], configs, rotation = 0)
plt.show()

# %%
plt.figure(figsize = (12,6))
plt.plot(all_outs[0])
plt.title("Config1")
plt.xlabel("Iteración")
plt.ylabel("Valor de la fx de evaluación (Calidad de la solución)")
#plt.xticks([1, 2, 3, 4], ['CP=1 DP=1 OP=1', 'CP=1 DP=1 OP=5', 'CP=1 DP=5 OP=1', 'CP=5 DP=1 OP=1'], rotation = 30)
plt.show()

# %%
plt.figure(figsize = (12,6))
plt.plot(all_outs[1])
plt.title("Config2")
plt.xlabel("Iteración")
plt.ylabel("Valor de la fx de evaluación (Calidad de la solución)")
#plt.xticks([1, 2, 3, 4], ['CP=1 DP=1 OP=1', 'CP=1 DP=1 OP=5', 'CP=1 DP=5 OP=1', 'CP=5 DP=1 OP=1'], rotation = 30)
plt.show()
